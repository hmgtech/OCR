# %% [markdown]
# ## <center> OCR By Pytesseract </center>
# Download: https://github.com/UB-Mannheim/tesseract/wiki<br>
#
# OpenCV: https://pypi.org/project/opencv-python/<br>
#
# Pytesseract: https://pypi.org/project/pytesseract/<br><br>
#
# <center><h1>Follow us for more on:<center></h1>
#
# Instagram: <a href="https://www.instagram.com/engg_tech.ai">https://www.instagram.com/engg_tech.ai/</a><br>
#
# Facebook: https://www.facebook.com/enggtechai<br>
#
# Youtube:   https://www.youtube.com/c/EnggtecH<br>
#
# Github: https://www.github.com/hmgtech<br>

# %% [markdown]
# <img src="1.JPG" alt="Drawing" style="width: 200px;" align="left"/>
#
# <img src="o.png" alt="Drawing" style="width: 200px;" align="right"/>

# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd = 'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'

# %%
import cv2

# %%
img = cv2.imread("1.jpg")
cv2.imshow('Image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread("2.png")
text = pytesseract.image_to_string(img)
print(text)
# Out:
# Machine learning (ML) is the study of computer algorithms that improve automatically through experience.!"] Itis seen as
# a subset of artificial intelligence. Machine learning algorithms build a model based on sample data, known as "training
# data", in order to make predictions or decisions without being explicitly programmed to do so.!2] Machine learning
# algorithms are used in a wide variety of applications, such as email filtering and computer vision, where it is difficult or
# infeasible to develop conventional algorithms to perform the needed tasks.
#
# A subset of machine learning is closely related to computational statistics, which focuses on making predictions using
# computers; but not all machine learning is statistical learning. The study of mathematical optimization delivers methods,
# theory and application domains to the field of machine learning. Data mining is a related field of study, focusing on
# ...

# %%
boxes = pytesseract.image_to_boxes(img)
print(boxes)
# Out:
# w 208 662 234 682 0
# e 235 662 253 682 0
# f 265 662 286 690 0
# a 284 662 302 690 0
# l 283 662 345 689 0
# l 319 662 337 690 0
# . 345 663 355 672 0
# w 193 607 220 627 0
# e 220 606 239 627 0
# b 248 606 270 634 0
# r 272 606 293 627 0
# e 294 606 313 627 0
# a 311 606 329 634 0
# k 314 606 358 634 0
# . 360 607 369 617 0
# w 207 551 234 571 0
# e 234 551 252 572 0
# f 264 551 285 580 0
# a 282 551 303 571 0
# i 299 551 322 580 0
# l 304 551 345 579 0
# . 346 552 356 562 0
# b 194 441 216 469 0
# u 216 441 241 461 0
# t 240 441 260 469 0
# t 270 441 289 469 0
# h 289 441 313 469 0
# e 313 441 332 461 0
# n 334 441 357 461 0
# , 358 434 368 452 0
# w 206 330 232 350 0
# e 233 330 251 351 0
# r 263 330 285 351 0
# i 282 330 304 358 0
# s 285 330 324 358 0
# e 326 330 345 351 0
# . 347 331 357 341 0
# w 205 275 231 295 0
# e 232 275 250 296 0
# h 261 275 285 303 0
# e 286 275 304 296 0
# a 306 275 324 303 0
# l 306 275 347 303 0
# . 348 276 358 286 0
# w 160 220 186 240 0
# ...

# %%
img = cv2.imread("1.jpg")
hImg, wImg,_ = img.shape
boxes = pytesseract.image_to_boxes(img)
for b in boxes.splitlines():
    print(b)
    b = b.split(' ')
    print(b)
# Out:
# w 208 662 234 682 0
# ['w', '208', '662', '234', '682', '0']
# e 235 662 253 682 0
# ['e', '235', '662', '253', '682', '0']
# f 265 662 286 690 0
# ['f', '265', '662', '286', '690', '0']
# a 284 662 302 690 0
# ['a', '284', '662', '302', '690', '0']
# l 283 662 345 689 0
# ['l', '283', '662', '345', '689', '0']
# l 319 662 337 690 0
# ['l', '319', '662', '337', '690', '0']
# . 345 663 355 672 0
# ['.', '345', '663', '355', '672', '0']
# w 193 607 220 627 0
# ['w', '193', '607', '220', '627', '0']
# e 220 606 239 627 0
# ['e', '220', '606', '239', '627', '0']
# b 248 606 270 634 0
# ['b', '248', '606', '270', '634', '0']
# r 272 606 293 627 0
# ['r', '272', '606', '293', '627', '0']
# e 294 606 313 627 0
# ['e', '294', '606', '313', '627', '0']
# a 311 606 329 634 0
# ['a', '311', '606', '329', '634', '0']
# k 314 606 358 634 0
# ['k', '314', '606', '358', '634', '0']
# . 360 607 369 617 0
# ['.', '360', '607', '369', '617', '0']
# w 207 551 234 571 0
# ...

# %%
img = cv2.imread("1.jpg")
hImg, wImg,_ = img.shape
boxes = pytesseract.image_to_boxes(img)
for b in boxes.splitlines():
    print(b)
    b = b.split(' ')
    print(b)
    x,y,w,h = int(b[1]),int(b[2]),int(b[3]),int(b[4])
    cv2.rectangle(img, (x,y), (x+w,y+h), (0,0,255),3)
cv2.imshow('Result',img)
cv2.waitKey(0)
# Out:
# w 208 662 234 682 0
# ['w', '208', '662', '234', '682', '0']
# e 235 662 253 682 0
# ['e', '235', '662', '253', '682', '0']
# f 265 662 286 690 0
# ['f', '265', '662', '286', '690', '0']
# a 284 662 302 690 0
# ['a', '284', '662', '302', '690', '0']
# l 283 662 345 689 0
# ['l', '283', '662', '345', '689', '0']
# l 319 662 337 690 0
# ['l', '319', '662', '337', '690', '0']
# . 345 663 355 672 0
# ['.', '345', '663', '355', '672', '0']
# w 193 607 220 627 0
# ['w', '193', '607', '220', '627', '0']
# e 220 606 239 627 0
# ['e', '220', '606', '239', '627', '0']
# b 248 606 270 634 0
# ['b', '248', '606', '270', '634', '0']
# r 272 606 293 627 0
# ['r', '272', '606', '293', '627', '0']
# e 294 606 313 627 0
# ['e', '294', '606', '313', '627', '0']
# a 311 606 329 634 0
# ['a', '311', '606', '329', '634', '0']
# k 314 606 358 634 0
# ['k', '314', '606', '358', '634', '0']
# . 360 607 369 617 0
# ['.', '360', '607', '369', '617', '0']
# w 207 551 234 571 0
# ...

# %%
img = cv2.imread("1.jpg")
hImg, wImg,_ = img.shape

boxes = pytesseract.image_to_boxes(img)
for b in boxes.splitlines():
#     print(b)
    b = b.split(' ')
#     print(b)
    x,y,w,h = int(b[1]),int(b[2]),int(b[3]),int(b[4])
    
    cv2.rectangle(img, (x,hImg-y), (w,hImg-h), (0,0,255),2)
cv2.imshow('Result',img)
cv2.waitKey(0)
# Out:
# -1

# %%
img = cv2.imread("1.jpg")
hImg, wImg,_ = img.shape

boxes = pytesseract.image_to_boxes(img)
for b in boxes.splitlines():
#     print(b)
    b = b.split(' ')
#     print(b)
    x,y,w,h = int(b[1]),int(b[2]),int(b[3]),int(b[4])
    
    cv2.rectangle(img, (x,hImg-y), (w,hImg-h), (0,0,255),2)
    cv2.putText(img, b[0], (x, hImg-y+25),cv2.FONT_HERSHEY_COMPLEX,1,(50,50,255),1)
cv2.imshow('Result',img)
cv2.waitKey(0)
# Out:
# -1

# %%
img = cv2.imread("2.png")
# text = pytesseract.image_to_string(img)
# print(text)
hImg, wImg,_ = img.shape

boxes = pytesseract.image_to_boxes(img)
for b in boxes.splitlines():
#     print(b)
    b = b.split(' ')
#     print(b)
    x,y,w,h = int(b[1]),int(b[2]),int(b[3]),int(b[4])
    
    cv2.rectangle(img, (x,hImg-y), (w,hImg-h), (0,0,255),2)
    cv2.putText(img, b[0], (x, hImg-y+25),cv2.FONT_HERSHEY_COMPLEX,1,(50,50,255),1)
cv2.imshow('Result',img)
cv2.waitKey(0)

# %%
img = cv2.imread("2.png")
# text = pytesseract.image_to_string(img)
# print(text)
hImg, wImg,_ = img.shape

boxes = pytesseract.image_to_boxes(img)

for b in boxes.splitlines():
    print(b)
    b = b.split(' ')
    print(b)
    x,y,w,h = int(b[1]),int(b[2]),int(b[3]),int(b[4])
    
    cv2.rectangle(img, (x,hImg-y), (w,hImg-h), (0,0,255),2)
    cv2.putText(img, b[0], (x, hImg-y+25),cv2.FONT_HERSHEY_COMPLEX,1,(50,50,255),1)
cv2.imshow('Result',img)
cv2.waitKey(0)
